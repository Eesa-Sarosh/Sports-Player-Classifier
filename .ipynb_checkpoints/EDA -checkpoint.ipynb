# %%
import numpy as np
import cv2
import re
import matplotlib
import shutil
import os
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import os
import requests
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)
driver = webdriver.Chrome(options=chrome_options)



def download_image(url, folder_name, num):

    # write image to file
    reponse = requests.get(url)
    if reponse.status_code == 200:
        with open(os.path.join(folder_name, str(num)+".jpg"), 'wb') as file:
            file.write(reponse.content)

main_folder_name = 'Images'
if not os.path.isdir(main_folder_name):
    os.makedirs(main_folder_name)

players = ["lionel_messi", "cristiano_ronaldo", "charles_leclerc", "alex_morgan"]
for j in range(len(players)):
    #creating player directory
    sub_folder_name = players[j]
    if not os.path.isdir(os.path.join(main_folder_name, sub_folder_name)):
        os.makedirs(os.path.join(main_folder_name, sub_folder_name))
    player = players[j].split("_")  # #creating search string
    search_string = player[0]+"+"+player[1]+"+"+"face"

    url = f"https://www.google.com/search?q={search_string}&source=lnms&tbm=isch"
    driver.get(url)
    time.sleep(7)
    for i in range(1, 55):
        img_url = ""
        #At div 25 we do not have images.
        if i % 25 != 0:
            try:
                image_container = driver.find_element(By.XPATH,f'//*[@id="islrg"]/div[1]/div[{i}]/a[1]/div[1]/img').click()
                time.sleep(3)
                img_url = driver.find_element(By.XPATH,'//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]').get_attribute("src")
                print(img_url)
                time.sleep(1)
            except:
                print("Could not click")
            try:
                if img_url !="":
                    download_image(img_url, os.path.join(main_folder_name, sub_folder_name), i)
            except:
                print("Could not download.")
# Out:
# https://i.pinimg.com/736x/fb/f3/0e/fbf30e10ac0c1cf9778a8aab7909a38f.jpg
# data:image/jpeg;base64,...
# Could not download.
# https://assets.gqindia.com/photos/627cfe9f59a30320660c3e52/1:1/w_1080,h_1080,c_limit/Lionel%20Messi.jpeg
# https://i.pinimg.com/736x/aa/0a/56/aa0a565da1ab0b1672b8fc6adea0b9b6.jpg
# https://www.gulftoday.ae/-/media/gulf-today/images/articles/business/2020/6/5/messi-750.ashx?h=450&w=750&hash=76F3F75D9BC9B90B4B68D031C08E4372
# data:image/jpeg;base64,...
# Could not download.
# data:image/jpeg;base64,...
# Could not download.
# https://media.gq.com/photos/57963b22d81463fa0e31f40f/16:9/w_2560%2Cc_limit/messi-hair.jpg
# Could not click
# data:image/jpeg;base64,...
# Could not download.
# data:image/jpeg;base64,...
# Could not download.
# data:image/jpeg;base64,...
# Could not download.
# data:image/jpeg;base64,...
# Could not download.
# https://img.freepik.com/premium-photo/lionel-messi-face-line-art_485374-728.jpg
# https://b.fssta.com/uploads/application/soccer/headshots/711.png
# data:image/jpeg;base64,...
# Could not download.
# data:image/jpeg;base64,...
# Could not download.
# data:image/jpeg;base64,...
# Could not download.
# data:image/jpeg;base64,...
# Could not download.
# data:image/jpeg;base64,...
# Could not download.
# https://e00-marca.uecdn.es/assets/multimedia/imagenes/2022/10/31/16672412505153.jpg
# https://wallpapercave.com/wp/wp7496007.jpg
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR8dW65UFDtrJZTCv7Tr6Yj5hJxyvDYy9tBOA&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQVQkJZHvMvVV77kA4mgryE2W-fI8NEgvIgHw&usqp=CAU
# Could not click
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSnaF5LEJgeS9Vy3yqdcmI9So0nzSVVo9JqsQ&usqp=CAU
# Could not click
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR49VR0HGNJJ8HrXXDZUIv_Q1eS87TGrbdUmA&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRXfx9mHVhM4nqdmQVy1gNGcIaAkTBAddNNug&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSYsH6ORE827QC57ER7-oejE-p1ZntT5-CKKQ&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTC8ezfFwxC9W_EbIqkfzWULkvIAHyGXt5uJg&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTpR1fnF0_LmmOKjzxuT9bcP2h7KHAwVZV3HA&usqp=CAU
# https://www.newarab.com/sites/default/files/1245129872.jpeg
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT7RQ-HF-25d6WxWRdOPXNb2oTlR89HY1jZ2A&usqp=CAU
# https://thefederal.com/file/2019/07/695877-lionel-messi-pti.jpg
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ

# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSCHzyNHZNn9BT5qzQ0U6_aYP2K7WRe3Bi6og&usqp=CAU
# https://cdn-attachments.timesofmalta.com/8eb93c481030dfcef54c7f9fea831a89d1176894-1561300796-5d0f8f3c-1920x1280.jpg
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTeD_cd9Ta9eME4hm2nULadBTY7CfTI2SomAQ&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRiV_tGcLILczBHJPKvDIldQuJskkApa4h37g&usqp=CAU
# https://banner2.cleanpng.com/20190522/iht/kisspng-alex-morgan-united-states-womens-national-soccer-5ce617e9ac5682.8879345515585832737059.jpg
# https://image-cdn.essentiallysports.com/wp-content/uploads/LeBron-James-Alex-Morgan-1110x1065.jpg
# Could not click
# https://ak.uecdn.es/p/110/thumbnail/entry_id/0_0okdxzys/width/1200/type/2/bgcolor/000000/0_0okdxzys.jpg
# Could not click
# Could not click
# Could not click
# Could not click

# %%
face_cascade = cv2.CascadeClassifier('opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('opencv/haarcascades/haarcascade_eye.xml')

# %%
scrapped_data = "Images/"
dataset_path = "cropped_dataset/"

# %%
import os
img_dirs = []
for entry in os.scandir(scrapped_data):
    if entry.is_dir() and entry.name != '.ipynb_checkpoints':
        img_dirs.append(entry.path)

# %%
dataset_images = []
names = {}
cropped_image_dirs = []

if os.path.exists(dataset_path):
     shutil.rmtree(dataset_path)         #delete current contents of the folder if folder exists

for img_dir in img_dirs:
    name = img_dir.split('/')[-1]        #get celebrity name from it directory
    print(name)
    names[name] = []
    c=1
    for entry in os.scandir(img_dir):
        path = entry.path
        path_str = re.sub(r'\\', '/', path)        #replace double backslash with frontslash to get image path
        img = cv2.imread(path_str)
        print(path_str)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)   #convert to greyscale
        faces_detected = face_cascade.detectMultiScale(gray, 1.3, 5)  #detect faces
        for (x,y,w,h) in faces_detected:
            gray_img_face = gray[y:y+h, x:x+w]                        #crop face in greyscale and colored image
            colored_face = img[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(gray_img_face)        #detect eyes to ensure image is clear
            if len(eyes) >= 2:                                        #only add image in dataset if full face with eyes visib
                new_dataset = dataset_path + name
                if not os.path.exists(new_dataset):
                    os.makedirs(new_dataset)
                    cropped_image_dirs.append(new_dataset)
                cropped_face = name + str(c) + ".jpg"
                file_path = new_dataset + "/" + cropped_face
                
                cv2.imwrite(file_path, colored_face)
                names[name].append(file_path)
                c += 1

# %%
import numpy as np
from random import randint

# Define the input and output directories
input_dir = "cropped_dataset/"


rotation_angles = [90, -90, 180]

for subfolder in os.listdir(input_dir):
    subfolder_path = os.path.join(input_dir, subfolder)
    print(subfolder_path)
  
    for filename in os.listdir(subfolder_path):
    
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_path = os.path.join(subfolder_path, filename)
            image = cv2.imread(image_path)
            
        angle = random.choice(rotation_angles)  # Applying augmentation
        if angle == 90:
            rotated_image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
        elif angle == -90:
            rotated_image = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE)
        else:
            rotated_image = cv2.rotate(image, cv2.ROTATE_180)
        
       
        output_filename = f"{os.path.splitext(filename)[0]}_aug_.jpg"
        output_path = os.path.join(subfolder_path, output_filename)
        cv2.imwrite(output_path, rotated_image)
